# %%
from __future__ import division

import random
import pyprind 

import egt
import species

# %matplotlib inline

# %% [markdown]
# # Hawk Dove simulation

# %% [markdown]
# [Example](https://www.stat.berkeley.edu/~aldous/157/Papers/haigh2.pdf)
#
# |   |Hawk|Dove|
# |---|---|---|
# |**Hawk**|-2|10|
# |**Dove**|0|3|

# %%
print("Expected ESS at Hawks p = {}%".format(7/9*100))
# Out:
# Expected ESS at Hawks p = 77.7777777778%

# %% [markdown]
# ### Run the simulation

# %%
NUMBER_OF_ITERATIONS = 100

# %% [markdown]
# ##### case 1

# %%
random.seed()
p = species.Population(number_of_hawks=5, number_of_doves=100)
g = egt.Game(population=p)
for _ in pyprind.prog_bar(range(0, NUMBER_OF_ITERATIONS)):
    g.advance()
    
print("\nRun complete \n")

g.population.describe()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Run complete
#
# Number of hawks = 1793
# Number of doves = 720
# Percent of hawks = 71.3489852766
# Percent of doves = 28.6510147234
# Total time elapsed: 14.210 sec

# %%
g.visualize('Case 1');

# %% [markdown]
# ##### case 2

# %%
random.seed()
p = species.Population(number_of_hawks=100, number_of_doves=5)
g = egt.Game(population=p)
for _ in pyprind.prog_bar(range(0, NUMBER_OF_ITERATIONS)):
    g.advance()
    
print("\nRun complete \n")

g.population.describe()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Run complete
#
# Number of hawks = 21
# Number of doves = 6
# Percent of hawks = 77.7777777778
# Percent of doves = 22.2222222222
# Total time elapsed: 0.105 sec

# %%
g.visualize('Case 2');

# %% [markdown]
# ##### case 3

# %%
random.seed()
p = species.Population(number_of_hawks=50, number_of_doves=50)
g = egt.Game(population=p)
for _ in pyprind.prog_bar(range(0, NUMBER_OF_ITERATIONS)):
    g.advance()
    
print("\nRun complete \n")

g.population.describe()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Run complete
#
# Number of hawks = 424
# Number of doves = 121
# Percent of hawks = 77.7981651376
# Percent of doves = 22.2018348624
# Total time elapsed: 1.297 sec

# %%
g.visualize('Case 3');

# %% [markdown]
# ### Special cases

# %%
random.seed()
p = species.Population(number_of_hawks=0, number_of_doves=100)
g = egt.Game(population=p)
for _ in pyprind.prog_bar(range(0, NUMBER_OF_ITERATIONS)):
    g.advance()

print("\nRun complete \n")
    
g.population.describe()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Run complete
#
# Number of hawks = 0
# Number of doves = 3200
# Percent of hawks = 0.0
# Percent of doves = 100.0
# Total time elapsed: 23.416 sec

# %%
g.visualize('Case 4');

# %%
random.seed()
p = species.Population(number_of_hawks=100, number_of_doves=0)
g = egt.Game(population=p)
for _ in pyprind.prog_bar(range(0, NUMBER_OF_ITERATIONS)):
    g.advance()
    
print("\nRun complete \n")

g.population.describe()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Run complete
#
# Number of hawks = 0
# Number of doves = 0
# Percent of hawks = 0.0
# Percent of doves = 0.0
# Total time elapsed: 0.064 sec

# %%
g.visualize('Case 5');

# %%
random.seed()
p = species.Population(number_of_hawks=150, number_of_doves=40)
g = egt.Game(population=p)
for _ in pyprind.prog_bar(range(0, NUMBER_OF_ITERATIONS)):
    g.advance()
    
print("\nRun complete \n")

g.population.describe()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Run complete
#
# Number of hawks = 253
# Number of doves = 70
# Percent of hawks = 78.3281733746
# Percent of doves = 21.6718266254
# Total time elapsed: 0.778 sec

# %%
g.visualize('Case 6');
